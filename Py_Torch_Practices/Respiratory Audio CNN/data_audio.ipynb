# %%
import os
import shutil
import numpy as np
import pandas as pd
import librosa                       # audio loading, analysis
import librosa.display                # waveform/spectrogram plotting
import soundfile as sf                # reliable .wav read/write
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pathlib import Path
from collections import Counter
from IPython.display import Audio, display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import librosa                       # audio loading, analysis
#       6 import librosa.display                # waveform/spectrogram plotting
#       7 import soundfile as sf                # reliable .wav read/write
#
# ModuleNotFoundError: No module named 'librosa'
