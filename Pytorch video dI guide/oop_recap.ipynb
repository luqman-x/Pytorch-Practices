# %%
class Item:
    #class artributes..
    pay_rate = 0.8
    all = []
    def __init__(self, name:str, price: int, quantity:int = 0) -> str:
       #Run validation to recieved arguments..
       assert price >=0, f"Price {price} is not greater than 0!"
       assert quantity >= 0,f"Quantity {quantity} is not greater than 0!"

       #Assign to self obj
       self.name = name
       self.quantity = quantity
       self.price = price
       

    #Actions to execute
       Item.all.append(self)


    def calculate_total_price(self):
        return self.quantity * self.price

    def apply_discount(self):
        self.price = self.price * self.pay_rate


item1 = Item("phone",500,  5)
item2 = Item("Laptop", 1000, 5)
item3 = Item("Cable", 10, 5)
Item4 = Item("Mouse", 50, 5)


item1.calculate_total_price()
item1.apply_discount()
print(item1.price)

print(Item.all)
# Out:
# 400.0
# [<__main__.Item object at 0x0000021A7DB43CB0>, <__main__.Item object at 0x0000021A7E260410>, <__main__.Item object at 0x0000021A7E261450>, <__main__.Item object at 0x0000021A7E37C2B0>]

# %%
for instance in Item.all:
    print(instance.name)
# Out:
# phone
# Laptop
# Cable
# Mouse
